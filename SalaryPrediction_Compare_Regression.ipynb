# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
import pandas as pd

dataset = pd.read_csv('/content/W8_Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values  # Ensure X is a matrix
y = dataset.iloc[:, 2].values

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
plt.scatter(X, y, color='red', label='Actual')
plt.plot(X, lin_reg.predict(X), color='blue', label='Linear Regression')

# %%
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
lin_reg_poly = LinearRegression()
lin_reg_poly.fit(X_poly, y)
plt.scatter(X, y, color='red', label='Actual')
plt.plot(X, lin_reg_poly.predict(X_poly), color='green', label='Polynomial Regression')

# %%
level = 6.5
lin_pred = lin_reg.predict([[level]])
poly_pred = lin_reg_poly.predict(poly_reg.transform([[level]]))

print(f"Linear Regression Prediction at level 6.5: {lin_pred[0]}")
print(f"Polynomial Regression Prediction at level 6.5: {poly_pred[0]}")
# Out:
# Linear Regression Prediction at level 6.5: 330378.78787878784
# Polynomial Regression Prediction at level 6.5: 158862.45265155006

# %%
plt.scatter(X, y, color='red', label='Actual')
plt.plot(X, lin_reg.predict(X), color='blue', label='Linear Regression')
plt.plot(X, lin_reg_poly.predict(poly_reg.transform(X)), color='green', label='Polynomial Regression')
plt.title('Position vs Salary')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %% [markdown]
# Linear regression fits a straight line across the data.
# It does not capture the curve or any nonlinear relationship between position level and salary.
# Result: It overestimates the salary at level 6.5, giving ~330k.
#
# Polynomial regression (with degree 4, as used in the code) fits a curve that better matches the actual distribution.
# It adapts to local patterns in the data.
# Result: The salary prediction (~158k) aligns more closely with what you'd expect in the mid-level positions (if the actual trend isn’t linear).
#
# The linear line missing most of the data points.
# The polynomial curve fitting smoothly across the real salaries — especially matching lower and higher levels better.
#
# Polynomial Regression is the better technique in this scenario, as it models the non-linear relationship between position level and salary more accurately.
